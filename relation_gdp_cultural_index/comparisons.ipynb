# %% [markdown]
# # Regression Analysis Cultura Data
#
# This notebook provides an overview of the statistical analysis that complements the main results in our paper. We primarily aim to test the hypothesis that the cultural production score can serve as a proxy for GDP. To evaluate this proposition, we use regression models where GDP is the dependent variable, and cultural production is one of the independent variables. We employ Bayesian Regression Modeling with Bambi—built upon PyMC—for a robust assessment of the correlation between these two variables. But before we delve into the models, we will first load and normalize the data to streamline the processing.
#
# ## Data Preparation

# %%
import numpy as np
import bambi as bmb
import pandas as pd
import arviz as az

# %%
df_gdp = pd.read_csv('../environnement_data/gdp_clean_region_name.csv', index_col=[0])
list(set(df_gdp.region_name))

df_unseen =  pd.read_csv('../unseen_species_model/results/occupation/unseen_data.csv', index_col=[0])
df_unseen = df_unseen.rename(columns={'decade':'year', 'count_cps':'score'})
df = pd.merge(df_gdp,df_unseen, on = ['region_name', 'year'])


df_unseen_occupation =  pd.read_csv('../unseen_species_model/results/occupation/unseen_data_occupation.csv', index_col=[0])
df_unseen_occupation = df_unseen_occupation.rename(columns={'decade':'year', 'count_cps':'score', 'N_est':'N_est_occupation'})
df_unseen_occupation = df_unseen_occupation.drop(['occupation', 'model_type', 'score', 'lower', 'upper'], axis=1)
df_unseen_occupation = df_unseen_occupation.groupby(['region_name', 'year']).sum().reset_index()

df = pd.merge(df,df_unseen_occupation, on = ['region_name', 'year'])
df
# Out:
#             region_code country_code_maddison  year  gdp_per_capita  \
# 0              re_italy                   ITA  1810            2558
# 1              re_italy                   ITA  1820            2665
# 2              re_italy                   ITA  1830            2657
# 3              re_italy                   ITA  1840            2711
# 4              re_italy                   ITA  1850            2611
# 5              re_italy                   ITA  1860            2573
# 6     re_eastern_europe                   POL  1820             818
# 7     re_eastern_europe                   POL  1830             942
# 8     re_eastern_europe                   POL  1840             907
# 9     re_eastern_europe                   POL  1850             985
# 10    re_eastern_europe                   POL  1860            1358
# 11  re_nordic_countries                   SWE  1810            1320
# 12  re_nordic_countries                   SWE  1820            1415
# 13  re_nordic_countries                   SWE  1830            1468
# 14  re_nordic_countries                   SWE  1840            1568
# 15  re_nordic_countries                   SWE  1850            1715
# 16  re_nordic_countries                   SWE  1860            1941
# 17     re_low_countries                   NLD  1820            3006
# 18     re_low_countries                   NLD  1830            3038
# 19     re_low_countries                   NLD  1840            3623
# 20     re_low_countries                   NLD  1850            3779
# 21     re_low_countries                   NLD  1860            3840
# 22            re_france                   FRA  1820            1809
# 23            re_france                   FRA  1830            1898
# 24            re_france                   FRA  1840            2276
# 25            re_france                   FRA  1850            2546
# 26            re_france                   FRA  1860            3016
# 27    re_united_kingdom                   GBR  1810            3478
# 28    re_united_kingdom                   GBR  1820            3306
# 29    re_united_kingdom                   GBR  1830            3550
# 30    re_united_kingdom                   GBR  1840            4018
# 31    re_united_kingdom                   GBR  1850            4332
# 32    re_united_kingdom                   GBR  1860            5086
#
#          region_name         N_est         lower         upper  model_type  \
# 0              Italy   4968.493110   4699.546484   5247.557146  base_model
# 1              Italy   6144.109914   5816.884697   6484.941816  base_model
# 2              Italy   5705.250076   5403.249546   6024.767578  base_model
# 3              Italy  10925.166062  10344.094800  11544.394156  base_model
# 4              Italy   9530.449502   9002.212715  10089.856780  base_model
# 5              Italy  12064.222449  11349.505997  12807.868564  base_model
# 6     Eastern Europe  15115.173714  14108.195892  16143.360501  base_model
# 7     Eastern Europe  14535.927539  13571.065217  15523.371923  base_model
# 8     Eastern Europe  23226.452790  21667.966594  24829.531396  base_model
# 9     Eastern Europe  24058.928735  22403.177657  25753.374507  base_model
# 10    Eastern Europe  32552.107666  30252.655519  34932.682055  base_model
# 11  Nordic countries   2245.687681   2063.860224   2434.052815  base_model
# 12  Nordic countries   2984.132348   2746.362639   3232.415841  base_model
# 13  Nordic countries   2952.660629   2719.198857   3197.934646  base_model
# 14  Nordic countries   4363.763803   4012.077549   4729.017353  base_model
# 15  Nordic countries   4600.539199   4226.560452   4992.714191  base_model
# 16  Nordic countries   6215.686187   5698.523371   6760.296809  base_model
# 17     Low countries   1624.235410   1535.920842   1711.650558  base_model
# 18     Low countries   1794.415043   1696.765293   1891.771590  base_model
# 19     Low countries   3476.490740   3287.498630   3666.468514  base_model
# 20     Low countries   3565.962178   3363.353604   3770.777345  base_model
# 21     Low countries   4286.824573   4028.630269   4548.649490  base_model
# 22            France   7060.743553   6787.750582   7344.202622  base_model
# 23            France   7653.701574   7361.977330   7954.366673  base_model
# 24            France  13202.109266  12690.663024  13728.592235  base_model
# 25            France  12889.963165  12354.661117  13443.183821  base_model
# 26            France  16365.310784  15594.495462  17153.460529  base_model
# 27    United Kingdom   3098.848141   2946.735451   3256.492963  base_model
# 28    United Kingdom   4524.272177   4306.241152   4748.340943  base_model
# 29    United Kingdom   4623.728731   4403.273201   4850.261441  base_model
# 30    United Kingdom   7350.244084   6991.493405   7712.773555  base_model
# 31    United Kingdom   7048.491462   6694.153700   7410.114973  base_model
# 32    United Kingdom   8713.011748   8238.435744   9201.815004  base_model
#
#     score  N_est_occupation
# 0     411      10666.943091
# 1     512      13813.057592
# 2     476      12112.367733
# 3     915      23501.604287
# 4     800      21135.841316
# 5    1015      30229.803095
# 6     808      24989.716101
# 7     780      24535.955347
# 8    1252      42349.569301
# 9    1301      43504.860667
# 10   1765      58483.244976
# 11    214       4404.922655
# 12    285       5619.618647
# 13    283       5272.327420
# 14    421       8906.945840
# 15    445       9550.351993
# 16    603      12529.992867
# 17    256       2797.070940
# 18    286       3522.134101
# 19    552       6444.892583
# 20    569       7228.705024
# 21    686       9227.445892
# 22    907      12082.320971
# 23    985      12065.048323
# 24   1707      21875.345721
# 25   1673      21854.543609
# 26   2128      28697.053056
# 27    419       5509.845809
# 28    613       7570.847286
# 29    629       6924.747467
# 30   1006      11849.468975
# 31    967      11601.848131
# 32   1196      14619.093491

# %%
df_gdp
# Out:
#            region_code country_code_maddison  year  gdp_per_capita  \
# 0             re_italy                   ITA  1810            2558
# 1             re_italy                   ITA  1811            2473
# 2             re_italy                   ITA  1812            2527
# 3             re_italy                   ITA  1813            2596
# 4             re_italy                   ITA  1814            2627
# ..                 ...                   ...   ...             ...
# 405  re_united_kingdom                   GBR  1876            5938
# 406  re_united_kingdom                   GBR  1877            5923
# 407  re_united_kingdom                   GBR  1878            5879
# 408  re_united_kingdom                   GBR  1879            5786
# 409  re_united_kingdom                   GBR  1880            5997
#
#         region_name
# 0             Italy
# 1             Italy
# 2             Italy
# 3             Italy
# 4             Italy
# ..              ...
# 405  United Kingdom
# 406  United Kingdom
# 407  United Kingdom
# 408  United Kingdom
# 409  United Kingdom
#
# [410 rows x 5 columns]

# %%
# Apply normalization

df["century"] = df["year"].round(-2)

df["score_log"] = np.log(df["score"])
df["score_log_std"] = df["score_log"] / df["score_log"].mean()


df["N_est_log"] = np.log(df["N_est"])
df["N_est_log_std"] = df["N_est_log"] / df["N_est_log"].mean()


df["log_gdp"] = np.log(df["gdp_per_capita"])
df["log_gdp_std"] = df["log_gdp"] / df["log_gdp"].mean()

df["N_est_occupation_log"] = np.log(df["N_est_occupation"])
df["N_est_occupation_log_std"] = df["N_est_occupation_log"] / df["N_est_occupation_log"].mean()

# %%
import matplotlib.pyplot as plt

plt.hist(df["log_gdp"].values, histtype="step", color="k", bins="fd");

# %% [markdown]
# We observe an intriguing trimodal structure. It was suggested by Charles that this might be due to "the fact that the Maddison data always tend to have an estimation for a region at date year=1 and then jump up to over year=1000". Filtering these instances, doesn't seem to alter the trimodal structure, however:

# %% [markdown]
# The trimodality of the data is somewhat hidden when plotting against the unnormalized score and bias-corrected score. However, after log transformation, the structure becomes visible again:

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(8, 6), constrained_layout=True)
axes = axes.flatten()

axes[0].scatter(df["score"], df["gdp_per_capita"], alpha=0.1, color="k")
axes[0].set_title("unnormalized score")

axes[1].scatter(df["N_est"], df["gdp_per_capita"], alpha=0.1, color="k")
axes[1].set_title("unnormalized N_est")

axes[2].scatter(df["score_log"], df["gdp_per_capita"], alpha=0.1, color="k")
axes[2].set_title("logged score")

axes[3].scatter(df["N_est_log"], df["gdp_per_capita"], alpha=0.1, color="k")
axes[3].set_title("logged N_est");

# %%
models = {}

# %%
priors = {
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "score_log_std|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
}

m_score_vi = bmb.Model(
    "log_gdp_std ~ score_log_std + (score_log_std|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True, 
    priors=priors
)

m_score_vi.build()
m_score_vi.graph()

# %%
m_score_vi_fit = m_score_vi.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.9,
    idata_kwargs={"log_likelihood": True}
)
models["log_gdp_std ~ score_log_std + (score_log_std|region_name)"] = m_score_vi_fit
az.summary(m_score_vi_fit)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, score_log_std, 1|region_name_sigma, 1|region_name_offset, score_log_std|region_name_sigma, score_log_std|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 01:08&lt;00:00 Sampling 4 chains, 543 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 68 seconds.
# There were 543 divergences after tuning. Increase `target_accept` or reparameterize.
#                                               mean     sd  hdi_3%  hdi_97%  \
# Intercept                                    0.738  0.076   0.588    0.881
# score_log_std                                0.260  0.056   0.156    0.369
# log_gdp_std_sigma                            0.011  0.002   0.008    0.015
# 1|region_name_sigma                          0.142  0.083   0.033    0.296
# score_log_std|region_name_sigma              0.086  0.063   0.000    0.198
# 1|region_name[Eastern Europe]               -0.132  0.089  -0.316    0.019
# 1|region_name[France]                       -0.081  0.093  -0.267    0.072
# 1|region_name[Italy]                         0.105  0.105  -0.060    0.325
# 1|region_name[Low countries]                 0.075  0.080  -0.066    0.233
# 1|region_name[Nordic countries]             -0.029  0.078  -0.185    0.105
# 1|region_name[United Kingdom]                0.043  0.078  -0.100    0.197
# score_log_std|region_name[Eastern Europe]    0.007  0.070  -0.132    0.143
# score_log_std|region_name[France]            0.050  0.073  -0.057    0.214
# score_log_std|region_name[Italy]            -0.082  0.088  -0.259    0.048
# score_log_std|region_name[Low countries]    -0.000  0.062  -0.116    0.136
# score_log_std|region_name[Nordic countries]  0.011  0.060  -0.104    0.130
# score_log_std|region_name[United Kingdom]    0.026  0.060  -0.078    0.163
#
#                                              mcse_mean  mcse_sd  ess_bulk  \
# Intercept                                        0.003    0.002     841.0
# score_log_std                                    0.002    0.001    1076.0
# log_gdp_std_sigma                                0.000    0.000    1012.0
# 1|region_name_sigma                              0.003    0.002     818.0
# score_log_std|region_name_sigma                  0.002    0.001     974.0
# 1|region_name[Eastern Europe]                    0.003    0.002     889.0
# 1|region_name[France]                            0.003    0.002     926.0
# 1|region_name[Italy]                             0.005    0.004     528.0
# 1|region_name[Low countries]                     0.003    0.002     744.0
# 1|region_name[Nordic countries]                  0.003    0.002     715.0
# 1|region_name[United Kingdom]                    0.003    0.002     926.0
# score_log_std|region_name[Eastern Europe]        0.003    0.003     726.0
# score_log_std|region_name[France]                0.003    0.002     871.0
# score_log_std|region_name[Italy]                 0.004    0.003     569.0
# score_log_std|region_name[Low countries]         0.002    0.001    1269.0
# score_log_std|region_name[Nordic countries]      0.001    0.001    2372.0
# score_log_std|region_name[United Kingdom]        0.002    0.001    1453.0
#
#                                              ess_tail  r_hat
# Intercept                                       364.0   1.01
# score_log_std                                   481.0   1.00
# log_gdp_std_sigma                              2030.0   1.00
# 1|region_name_sigma                            1598.0   1.00
# score_log_std|region_name_sigma                2333.0   1.00
# 1|region_name[Eastern Europe]                   467.0   1.00
# 1|region_name[France]                          1668.0   1.00
# 1|region_name[Italy]                            266.0   1.01
# 1|region_name[Low countries]                    865.0   1.01
# 1|region_name[Nordic countries]                 841.0   1.01
# 1|region_name[United Kingdom]                  1603.0   1.01
# score_log_std|region_name[Eastern Europe]       419.0   1.00
# score_log_std|region_name[France]               572.0   1.00
# score_log_std|region_name[Italy]                586.0   1.01
# score_log_std|region_name[Low countries]        504.0   1.00
# score_log_std|region_name[Nordic countries]    2714.0   1.00
# score_log_std|region_name[United Kingdom]       516.0   1.00

# %%
m_score_vi.predict(m_score_vi_fit, kind="pps")
az.plot_ppc(m_score_vi_fit)
# Out:
# <Axes: xlabel='log_gdp_std / log_gdp_std'>

# %%
az.plot_forest(
    data=m_score_vi_fit, 
    figsize=(6, 4), 
    var_names=["score_log_std|region_name"], 
    r_hat=True, 
    combined=True, 
    textsize=8
);

# %%
import xarray as xr
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_score_vi_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["score_log_std"]
    score = np.array([0, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    slope_specific_0 = posterior["score_log_std|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = (slope_common + slope_specific_0)

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["score_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="score (log std)", title=region_name)

# %%
from matplotlib.lines import Line2D

intercept_group_specific = posterior["1|region_name"]
slope_group_specific = posterior["score_log_std|region_name"]

a = intercept_common + intercept_group_specific
b = slope_common + slope_group_specific

score_xi = xr.DataArray(score)

fig, ax = plt.subplots()
for region in df["region_name"].unique():

    a_region = a.sel(region_name__factor_dim=region)
    b_region = b.sel(region_name__factor_dim=region)
    
    Y = (a_region + b_region * score_xi)
    Y_mean = Y.mean(axis=0)

    color = ("C0" if (Y[:, 1].quantile(0.025) > Y[:, 0].quantile(0.975)) else 
             "C1" if (Y[:, 0].quantile(0.025) > Y[:, 1].quantile(0.975)) else 
             "grey")
    ax.plot(score_xi, Y_mean, color=color, alpha=0.7, lw=0.8, label=region)
    ax.text(
        score_xi[-1],
        Y_mean[-1],
        " — " + region,
        size="small",
        color=color,
        ha="left",
        va="center",
    )
    
ax.spines[['right', 'top']].set_visible(False)
custom_lines = [Line2D([0], [0], color=c, lw=1) for c in ("C0", "C1", "grey")]
ax.legend(custom_lines, ['positive relationship', 'negative relationship', 'inconclusive relationship'], 
           loc="upper center", ncol=4, bbox_to_anchor=(0.5, 1.1), frameon=False)
ax.set(ylabel="gdp (log, std)", xlabel="Score (log std)");

# %% [markdown]
# We perform the same analysis, swapping the cultural production score for the bias-corrected score:

# %%
m_est_vi = bmb.Model(
    "log_gdp_std ~ N_est_log_std + (N_est_log_std|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True,
    priors={
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "N_est_log_std|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
})

m_est_vi_fit = m_est_vi.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.9,
    idata_kwargs={"log_likelihood": True})

az.summary(m_est_vi_fit)

models["log_gdp_std ~ N_est_log_std + (N_est_log_std|region_name)"] = m_est_vi_fit
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, N_est_log_std, 1|region_name_sigma, 1|region_name_offset, N_est_log_std|region_name_sigma, N_est_log_std|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 01:26&lt;00:00 Sampling 4 chains, 1,157 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 86 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# There were 1157 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
waic_compare = az.compare(models, ic='LOO')
az.plot_compare(waic_compare, insample_dev=True)
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:1037: RuntimeWarning: overflow encountered in exp
#   weights = 1 / np.exp(len_scale - len_scale[:, None]).sum(axis=1)
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'log' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/plots/backends/matplotlib/compareplot.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   scale = comp_df["scale"][0]
# <Axes: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_loo (log)', ylabel='ranked models'>

# %%
import xarray as xr
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_est_vi_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["N_est_log_std"]
    score = np.array([0, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    slope_specific_0 = posterior["N_est_log_std|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = (slope_common + slope_specific_0)

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["N_est_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="N_est (log std)", title=region_name)

# %%
from matplotlib.lines import Line2D


intercept_group_specific = posterior["1|region_name"]
slope_group_specific = posterior["N_est_log_std|region_name"]

a = intercept_common + intercept_group_specific
b = slope_common + slope_group_specific

score_xi = xr.DataArray(score)

fig, ax = plt.subplots()
for region in df["region_name"].unique():

    a_region = a.sel(region_name__factor_dim=region)
    b_region = b.sel(region_name__factor_dim=region)
    
    Y = (a_region + b_region * score_xi)
    Y_mean = Y.mean(axis=0)

    color = ("C0" if (Y[:, 1].quantile(0.025) > Y[:, 0].quantile(0.975)) else 
             "C1" if (Y[:, 0].quantile(0.025) > Y[:, 1].quantile(0.975)) else 
             "grey")
    ax.plot(score_xi, Y_mean, color=color, alpha=0.7, lw=0.8, label=region)
    ax.text(
        score_xi[-1],
        Y_mean[-1],
        " — " + region,
        size="small",
        color=color,
        ha="left",
        va="center",
    )
    
ax.spines[['right', 'top']].set_visible(False)
custom_lines = [Line2D([0], [0], color=c, lw=1) for c in ("C0", "C1", "grey")]
ax.legend(custom_lines, ['positive relationship', 'negative relationship', 'inconclusive relationship'], 
           loc="upper center", ncol=4, bbox_to_anchor=(0.5, 1.1), frameon=False)
ax.set(ylabel="gdp (log, std)", xlabel="N_est (log std)");

# %% [markdown]
# The fit appears to bear similarity to the prior model, and once more, the incorporated unidirectional relationship yields comparatively large residuals.

# %%
m_est_occupation_vi = bmb.Model(
    "log_gdp_std ~ N_est_occupation_log_std + (N_est_occupation_log_std|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True,
    priors={
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "N_est_occupation_log_std|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
})


m_est_occupation_vi_fit = m_est_occupation_vi.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.9,
    idata_kwargs={"log_likelihood": True})

az.summary(m_est_occupation_vi_fit)

models["log_gdp_std ~ N_est_occupation_log_std + (N_est_occupation_log_std|region_name)"] = m_est_vi_fit
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, N_est_occupation_log_std, 1|region_name_sigma, 1|region_name_offset, N_est_occupation_log_std|region_name_sigma, N_est_occupation_log_std|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 01:21&lt;00:00 Sampling 4 chains, 630 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 82 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# There were 630 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
waic_compare = az.compare(models, ic='LOO')
az.plot_compare(waic_compare, insample_dev=True)
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:1037: RuntimeWarning: overflow encountered in exp
#   weights = 1 / np.exp(len_scale - len_scale[:, None]).sum(axis=1)
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:1037: RuntimeWarning: overflow encountered in exp
#   weights = 1 / np.exp(len_scale - len_scale[:, None]).sum(axis=1)
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'log' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/plots/backends/matplotlib/compareplot.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   scale = comp_df["scale"][0]
# <Axes: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_loo (log)', ylabel='ranked models'>

# %%
waic_compare = az.compare(models, ic='WAIC')
az.plot_compare(waic_compare, insample_dev=True)
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:1645: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:1645: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:1645: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'log' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/plots/backends/matplotlib/compareplot.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   scale = comp_df["scale"][0]
# <Axes: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_waic (log)', ylabel='ranked models'>

# %%
import xarray as xr


fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_est_occupation_vi_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior['N_est_occupation_log_std']
    score = np.array([0, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    slope_specific_0 = posterior[f"{'N_est_occupation_log_std'}|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = (slope_common + slope_specific_0)

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0['N_est_occupation_log_std'], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel='N_est_occupation_log_std', title=region_name)

# %%
from matplotlib.lines import Line2D


intercept_group_specific = posterior["1|region_name"]
slope_group_specific = posterior["N_est_occupation_log_std|region_name"]

a = intercept_common + intercept_group_specific
b = slope_common + slope_group_specific

score_xi = xr.DataArray(score)

fig, ax = plt.subplots()
for region in df["region_name"].unique():

    a_region = a.sel(region_name__factor_dim=region)
    b_region = b.sel(region_name__factor_dim=region)
    
    Y = (a_region + b_region * score_xi)
    Y_mean = Y.mean(axis=0)

    color = ("C0" if (Y[:, 1].quantile(0.025) > Y[:, 0].quantile(0.975)) else 
             "C1" if (Y[:, 0].quantile(0.025) > Y[:, 1].quantile(0.975)) else 
             "grey")
    ax.plot(score_xi, Y_mean, color=color, alpha=0.7, lw=0.8, label=region)
    ax.text(
        score_xi[-1],
        Y_mean[-1],
        " — " + region,
        size="small",
        color=color,
        ha="left",
        va="center",
    )
    
ax.spines[['right', 'top']].set_visible(False)
custom_lines = [Line2D([0], [0], color=c, lw=1) for c in ("C0", "C1", "grey")]
ax.legend(custom_lines, ['positive relationship', 'negative relationship', 'inconclusive relationship'], 
           loc="upper center", ncol=4, bbox_to_anchor=(0.5, 1.1), frameon=False)
ax.set(ylabel="gdp (log, std)", xlabel='N_est_occupation_log_std')
# Out:
# [Text(0, 0.5, 'gdp (log, std)'), Text(0.5, 0, 'N_est_occupation_log_std')]

# %%
waic_compare = az.compare(models, ic='LOO')
az.plot_compare(waic_compare, insample_dev=True)
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'log' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/plots/backends/matplotlib/compareplot.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   scale = comp_df["scale"][0]
# <Axes: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_loo (log)', ylabel='ranked models'>

# %%
import xarray as xr

fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_est_vi_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["N_est_log_std"]
    score = np.array([0, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = slope_common

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["N_est_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="N est (log std)", title=region_name)

# %%
posterior = az.extract(m_est_vi_fit)
intercept_common = posterior["Intercept"]
slope_common = posterior["N_est_log_std"]
score = np.array([0, 2])

intercept_group_specific = posterior["1|region_name"]
a = intercept_common.mean() + intercept_group_specific.mean("sample")
b = slope_common.mean()
score_xi = xr.DataArray(score)
plt.plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.7, lw=0.8)
plt.ylabel("gdp (log, std)")
plt.xlabel("N est (log std)");

# %% [markdown]
# #### Model comparison
#
# We undertake a comparison of all models explored thus far, this time employing approximate leave-one-out cross-validation (LOO). The model incorporating varying intercepts on region and using cultural score as a global predictor appears to best fit the data. As expected, it is closely followed by the model utilizing bias-corrected cultural production scores. All models featuring varying intercepts significantly outperform those with a singular global intercept. The results are demonstrated in the subsequent table and accompanying figure.

# %%
waic_compare = az.compare(models, ic='LOO')
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'log' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (

# %%
waic_compare
# Out:
#                                                rank   elpd_loo     p_loo  \
# log_gdp_std ~ N_est_log_std + (1|region_name)     0  94.361043  7.102702
# log_gdp_std ~ score_log_std + (1|region_name)     1  94.249527  7.235700
#
#                                                elpd_diff  weight        se  \
# log_gdp_std ~ N_est_log_std + (1|region_name)   0.000000     1.0  3.497571
# log_gdp_std ~ score_log_std + (1|region_name)   0.111515     0.0  3.504112
#
#                                                     dse  warning scale
# log_gdp_std ~ N_est_log_std + (1|region_name)  0.000000    False   log
# log_gdp_std ~ score_log_std + (1|region_name)  0.104048    False   log

# %%
az.plot_compare(waic_compare, insample_dev=True);
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/plots/backends/matplotlib/compareplot.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   scale = comp_df["scale"][0]

# %%
az.plot_compare(waic_compare.loc[waic_compare.index.str.contains("1|region_name")], insample_dev=True);
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/plots/backends/matplotlib/compareplot.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   scale = comp_df["scale"][0]

# %% [markdown]
# ### Varying Slopes for Cultural Production in Different Regions
#
# In our previous analysis, we presumed a global, uniform effect of cultural production on GDP per capita. However, upon observing significant discrepancies in the GDP intercepts per region, it's plausible that the relationship's slope between the cultural production score and GDP also varies. To cater to this, we construct a varying slope model with the following specification:
#
# \begin{align*}
# \log(\text{GDP}_i) & \sim \text{Normal}(\mu_i, \sigma) \\
# \mu_i & = \alpha + \alpha_{\text{region}[i]} + (\beta + \beta_{\text{region}[i]}) x_i \\
# \alpha_\text{region} & \sim \text{Normal}(0, \sigma_{\alpha}) \\
# \beta_\text{region} & \sim \text{Normal}(0, \sigma_{\beta}) \\
# \alpha & \sim \text{Normal}(1, 1) \\
# \beta & \sim \text{Normal}(0, 1) \\
# \sigma_{\alpha} & \sim \text{HalfNormal}(1) \\
# \sigma_{\beta} & \sim \text{HalfNormal}(1) \\
# \sigma & \sim \text{Exponential}(1)
# \end{align*}
#
# As daunting as this might seem, it can be implemented relatively straightforward, as shown below. Also note that we could further improve the model by modeling the dependence of the priors on the varying slopes and intercepts. For now we treat them as independent priors, which may not be the most efficient way to do it.

# %%
priors = {
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "score_log_std|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
}

m_score_vs = bmb.Model(
    "log_gdp_std ~ score_log_std + (score_log_std|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True,
    priors=priors
)
m_score_vs
# Out:
#        Formula: log_gdp_std ~ score_log_std + (score_log_std|region_name)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 33
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 1.0, sigma: 1.0)
#             score_log_std ~ Normal(mu: 0.0, sigma: 1.0)
#
#         Group-level effects
#             1|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             score_log_std|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#
#         Auxiliary parameters
#             sigma ~ Exponential(lam: 1.0)

# %% [markdown]
# The model graph looks as follows:

# %%
m_score_vs.build()
m_score_vs.graph()

# %% [markdown]
# Despite a considerable surge in the model's complexity, efficient sampling persists, marked by commendable $\hat{r}$ values and satisfactory effective sample sizes. The model's summary is provided below. A key observation we promptly make is the elimination of the unmistakably positive main, global effect of the cultural production score. Instead, it intersects 0 within the 97% confidence intervals, suggesting the effect is not solely positive. We'll elaborate on this further in the ensuing section.

# %%
m_score_vs_fit = m_score_vs.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.9,
    idata_kwargs={"log_likelihood": True})

models["log_gdp_std ~ score_log_std + (score_log_std|region_name)"] = m_score_vs_fit
az.summary(m_score_vs_fit)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, score_log_std, 1|region_name_sigma, 1|region_name_offset, score_log_std|region_name_sigma, score_log_std|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 01:19&lt;00:00 Sampling 4 chains, 608 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 79 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# There were 608 divergences after tuning. Increase `target_accept` or reparameterize.
#                                               mean     sd  hdi_3%  hdi_97%  \
# Intercept                                    0.735  0.075   0.591    0.876
# score_log_std                                0.263  0.054   0.164    0.368
# log_gdp_std_sigma                            0.011  0.002   0.008    0.015
# 1|region_name_sigma                          0.150  0.087   0.028    0.308
# score_log_std|region_name_sigma              0.097  0.072   0.000    0.212
# 1|region_name[Eastern Europe]               -0.136  0.093  -0.324    0.023
# 1|region_name[France]                       -0.095  0.106  -0.317    0.070
# 1|region_name[Italy]                         0.119  0.106  -0.060    0.320
# 1|region_name[Low countries]                 0.078  0.079  -0.062    0.244
# 1|region_name[Nordic countries]             -0.028  0.077  -0.177    0.124
# 1|region_name[United Kingdom]                0.043  0.078  -0.100    0.199
# score_log_std|region_name[Eastern Europe]    0.009  0.072  -0.134    0.149
# score_log_std|region_name[France]            0.061  0.081  -0.050    0.229
# score_log_std|region_name[Italy]            -0.096  0.099  -0.283    0.043
# score_log_std|region_name[Low countries]    -0.004  0.063  -0.134    0.115
# score_log_std|region_name[Nordic countries]  0.010  0.060  -0.102    0.136
# score_log_std|region_name[United Kingdom]    0.025  0.060  -0.093    0.141
#
#                                              mcse_mean  mcse_sd  ess_bulk  \
# Intercept                                        0.002    0.002     902.0
# score_log_std                                    0.001    0.001    2605.0
# log_gdp_std_sigma                                0.000    0.000     218.0
# 1|region_name_sigma                              0.004    0.003     381.0
# score_log_std|region_name_sigma                  0.004    0.003     300.0
# 1|region_name[Eastern Europe]                    0.006    0.004     323.0
# 1|region_name[France]                            0.011    0.008     137.0
# 1|region_name[Italy]                             0.004    0.003     633.0
# 1|region_name[Low countries]                     0.002    0.002    1536.0
# 1|region_name[Nordic countries]                  0.002    0.002    1332.0
# 1|region_name[United Kingdom]                    0.003    0.002     499.0
# score_log_std|region_name[Eastern Europe]        0.002    0.001     839.0
# score_log_std|region_name[France]                0.007    0.005     200.0
# score_log_std|region_name[Italy]                 0.007    0.005     244.0
# score_log_std|region_name[Low countries]         0.001    0.001    1977.0
# score_log_std|region_name[Nordic countries]      0.001    0.001    1673.0
# score_log_std|region_name[United Kingdom]        0.001    0.001    2678.0
#
#                                              ess_tail  r_hat
# Intercept                                      1724.0   1.01
# score_log_std                                  2781.0   1.03
# log_gdp_std_sigma                               866.0   1.02
# 1|region_name_sigma                            1167.0   1.01
# score_log_std|region_name_sigma                2337.0   1.02
# 1|region_name[Eastern Europe]                  1282.0   1.02
# 1|region_name[France]                           102.0   1.04
# 1|region_name[Italy]                           1562.0   1.00
# 1|region_name[Low countries]                   1767.0   1.01
# 1|region_name[Nordic countries]                1826.0   1.01
# 1|region_name[United Kingdom]                  1863.0   1.02
# score_log_std|region_name[Eastern Europe]      2013.0   1.01
# score_log_std|region_name[France]               461.0   1.02
# score_log_std|region_name[Italy]                615.0   1.02
# score_log_std|region_name[Low countries]       2773.0   1.00
# score_log_std|region_name[Nordic countries]    3305.0   1.01
# score_log_std|region_name[United Kingdom]      2539.0   1.02

# %% [markdown]
# Echoing our previous approach, we conduct a posterior predictive check and find that the model aligns with the data far more effectively. The difference with the simpler models is really remarkable:

# %%
m_score_vs.predict(m_score_vs_fit, kind="pps")
az.plot_ppc(m_score_vs_fit);

# %% [markdown]
# The superior model fit becomes palpably apparent when we map the posterior predictions against the observations per region. In most instances, the varying slopes seem to align seamlessly with the data. A vital insight garnered from this plot is that the relationship between GDP and cultural production isn't universally positive across all regions. A pronounced positive correlation between the two variables is noticeable for the Low Countries, the United Kingdom, Japan, and to a slightly lesser degree, Spain. Conversely, the relationship appears inverted for the Chinese World, Eastern Europe, Italy, and the Arabic World. Portugal, France, and Central Europe do not appear to exhibit a distinct relationship, neither positive nor negative.

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_score_vs_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["score_log_std"]
    score = np.array([0, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    slope_specific_0 = posterior["score_log_std|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = (slope_common + slope_specific_0)

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["score_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="score (log std)", title=region_name)

# %% [markdown]
# The ensuing plot illustrates the mean posterior distribution for each region, facilitating a more discernible understanding of regions that showcase a positive correlation between GDP and cultural production, and those that bear a negative or ambiguous relationship. The plot vividly indicates that some regions maintain a positive association, while others harbor a negative one. Thus, this analysis affirms that the incorporation of varying slopes in our model was justified and introduces valuable nuance to our exploration. **It underlines that we cannot unequivocally assert a positive correlation between cultural production and GDP, as this relationship varies by region.**

# %%
from matplotlib.lines import Line2D

intercept_group_specific = posterior["1|region_name"]
slope_group_specific = posterior["score_log_std|region_name"]

a = intercept_common + intercept_group_specific
b = slope_common + slope_group_specific

score_xi = xr.DataArray(score)

fig, ax = plt.subplots()
for region in df["region_name"].unique():

    a_region = a.sel(region_name__factor_dim=region)
    b_region = b.sel(region_name__factor_dim=region)
    
    Y = (a_region + b_region * score_xi)
    Y_mean = Y.mean(axis=0)

    color = ("C0" if (Y[:, 1].quantile(0.025) > Y[:, 0].quantile(0.975)) else 
             "C1" if (Y[:, 0].quantile(0.025) > Y[:, 1].quantile(0.975)) else 
             "grey")
    ax.plot(score_xi, Y_mean, color=color, alpha=0.7, lw=0.8, label=region)
    ax.text(
        score_xi[-1],
        Y_mean[-1],
        " — " + region,
        size="small",
        color=color,
        ha="left",
        va="center",
    )
    
ax.spines[['right', 'top']].set_visible(False)
custom_lines = [Line2D([0], [0], color=c, lw=1) for c in ("C0", "C1", "grey")]
ax.legend(custom_lines, ['positive relationship', 'negative relationship', 'inconclusive relationship'], 
           loc="upper center", ncol=4, bbox_to_anchor=(0.5, 1.1), frameon=False)
ax.set(ylabel="gdp (log, std)", xlabel="score (log std)");

# %% [markdown]
# #### Covarying slopes and intercepts
#
# To further scrutinize the region-specific slope attributes, we illustrate the covariance between region-specific intercepts and slopes. The hypothesis is the potential correlation between the intercepts and slopes, which may indicate, for instance, an enhanced or diminished GDP increase or decrease corresponding to higher or lower intercepts. The ensuing plot depicts this relationship. Although most regions don't seem to manifest a distinctly pronounced relationship between intercepts and slopes, there are a handful of intriguing cases where interaction is noticeable. For instance, in the German world, the Greek world, and in the Latin world, a negative correlation is observed, implying a decrease in slope as the intercept escalates. Contrarily, regions like the Low Countries, although having an average intercept (hence its position around zero), boast an above-average slope. On the other hand, the Chinese world, despite having an average intercept, showcases a below-average slope.

# %%
import matplotlib

regions = df["region_name"].unique()

fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), sharex=True, sharey=True, constrained_layout=True)

# #  extract a subsample from the posterior and stack the chain and draw dims
posterior = az.extract(m_score_vs_fit, num_samples=500)
for i, (region, ax) in enumerate(zip(regions, axes.flatten())):
    post = posterior.sel(region_name__factor_dim=region)
    X = post["1|region_name"].data
    Y = post["score_log_std|region_name"].data
    ax.scatter(
        X, Y,
        facecolor="C1", edgecolor="none", alpha=0.2)
    ax.set(title=region)

    ax.axhline(c="0.25", ls="--")
    ax.axvline(c="0.25", ls="--")
    
fig.supylabel('Region-specific slope')
fig.supxlabel('Region-specific intercept');
plt.savefig("covariance-plot.pdf")

# %% [markdown]
# Below, I repeat the analysis, again swapping cultural production for the bias-corrected score.

# %%
priors = {
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "N_est_log_std|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
}

m_est_vs = bmb.Model(
    "log_gdp_std ~  N_est_log_std + (N_est_log_std|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True,
    priors=priors
)
m_est_vs
# Out:
#        Formula: log_gdp_std ~  N_est_log_std + (N_est_log_std|region_name)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 33
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 1.0, sigma: 1.0)
#             N_est_log_std ~ Normal(mu: 0.0, sigma: 1.0)
#
#         Group-level effects
#             1|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             N_est_log_std|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#
#         Auxiliary parameters
#             sigma ~ Exponential(lam: 1.0)

# %%
m_est_vs_fit = m_est_vs.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.95,
    idata_kwargs={"log_likelihood": True})

models["log_gdp_std ~ N_est_log_std + (N_est_log_std|region_name)"] = m_est_vs_fit
az.summary(m_est_vs_fit)

# NB: hitting max_treedepth is not much of a concern, at least not for model validity
# For more information about this and other warnings, see https://mc-stan.org/misc/warnings.html
# TODO, see if we can improve efficiency
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, N_est_log_std, 1|region_name_sigma, 1|region_name_offset, N_est_log_std|region_name_sigma, N_est_log_std|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 02:02&lt;00:00 Sampling 4 chains, 113 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 123 seconds.
# There were 113 divergences after tuning. Increase `target_accept` or reparameterize.
#                                               mean     sd  hdi_3%  hdi_97%  \
# Intercept                                    0.641  0.094   0.463    0.819
# N_est_log_std                                0.355  0.077   0.219    0.506
# log_gdp_std_sigma                            0.012  0.002   0.008    0.015
# 1|region_name_sigma                          0.161  0.106   0.000    0.349
# N_est_log_std|region_name_sigma              0.110  0.094   0.000    0.271
# 1|region_name[Eastern Europe]               -0.147  0.113  -0.371    0.052
# 1|region_name[France]                       -0.080  0.116  -0.319    0.101
# 1|region_name[Italy]                         0.117  0.135  -0.084    0.392
# 1|region_name[Low countries]                 0.093  0.098  -0.088    0.283
# 1|region_name[Nordic countries]             -0.031  0.095  -0.220    0.158
# 1|region_name[United Kingdom]                0.051  0.097  -0.132    0.235
# N_est_log_std|region_name[Eastern Europe]   -0.002  0.093  -0.180    0.183
# N_est_log_std|region_name[France]            0.061  0.102  -0.095    0.283
# N_est_log_std|region_name[Italy]            -0.098  0.119  -0.343    0.063
# N_est_log_std|region_name[Low countries]     0.001  0.083  -0.169    0.155
# N_est_log_std|region_name[Nordic countries]  0.012  0.082  -0.148    0.172
# N_est_log_std|region_name[United Kingdom]    0.032  0.081  -0.110    0.209
#
#                                              mcse_mean  mcse_sd  ess_bulk  \
# Intercept                                        0.002    0.001    2902.0
# N_est_log_std                                    0.001    0.001    3153.0
# log_gdp_std_sigma                                0.000    0.000    1342.0
# 1|region_name_sigma                              0.003    0.002     883.0
# N_est_log_std|region_name_sigma                  0.003    0.002     854.0
# 1|region_name[Eastern Europe]                    0.002    0.002    2525.0
# 1|region_name[France]                            0.003    0.002    1991.0
# 1|region_name[Italy]                             0.004    0.003    1069.0
# 1|region_name[Low countries]                     0.002    0.002    2429.0
# 1|region_name[Nordic countries]                  0.002    0.002    2910.0
# 1|region_name[United Kingdom]                    0.002    0.002    2735.0
# N_est_log_std|region_name[Eastern Europe]        0.002    0.001    2204.0
# N_est_log_std|region_name[France]                0.003    0.002    1434.0
# N_est_log_std|region_name[Italy]                 0.004    0.003    1198.0
# N_est_log_std|region_name[Low countries]         0.002    0.001    2803.0
# N_est_log_std|region_name[Nordic countries]      0.002    0.001    3086.0
# N_est_log_std|region_name[United Kingdom]        0.001    0.001    3362.0
#
#                                              ess_tail  r_hat
# Intercept                                      2574.0    1.0
# N_est_log_std                                  2834.0    1.0
# log_gdp_std_sigma                              3422.0    1.0
# 1|region_name_sigma                            1475.0    1.0
# N_est_log_std|region_name_sigma                2289.0    1.0
# 1|region_name[Eastern Europe]                  2676.0    1.0
# 1|region_name[France]                          2553.0    1.0
# 1|region_name[Italy]                           2002.0    1.0
# 1|region_name[Low countries]                   2140.0    1.0
# 1|region_name[Nordic countries]                2675.0    1.0
# 1|region_name[United Kingdom]                  2813.0    1.0
# N_est_log_std|region_name[Eastern Europe]      2707.0    1.0
# N_est_log_std|region_name[France]              2647.0    1.0
# N_est_log_std|region_name[Italy]               2611.0    1.0
# N_est_log_std|region_name[Low countries]       3187.0    1.0
# N_est_log_std|region_name[Nordic countries]    2797.0    1.0
# N_est_log_std|region_name[United Kingdom]      3229.0    1.0

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_est_vs_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["N_est_log_std"]
    score = np.array([0, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    slope_specific_0 = posterior["N_est_log_std|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = (slope_common + slope_specific_0)

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["N_est_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="N_est (log std)", title=region_name)

# %%
from matplotlib.lines import Line2D

intercept_group_specific = posterior["1|region_name"]
slope_group_specific = posterior["N_est_log_std|region_name"]

a = intercept_common + intercept_group_specific
b = slope_common + slope_group_specific

score_xi = xr.DataArray(score)

fig, ax = plt.subplots()
for region in df["region_name"].unique():

    a_region = a.sel(region_name__factor_dim=region)
    b_region = b.sel(region_name__factor_dim=region)
    
    Y = (a_region + b_region * score_xi)
    Y_mean = Y.mean(axis=0)

    color = ("C0" if (Y[:, 1].quantile(0.025) > Y[:, 0].quantile(0.975)) else 
             "C1" if (Y[:, 0].quantile(0.025) > Y[:, 1].quantile(0.975)) else 
             "grey")
    ax.plot(score_xi, Y_mean, color=color, alpha=0.7, lw=0.8, label=region)
    ax.text(
        score_xi[-1],
        Y_mean[-1],
        " — " + region,
        size="small",
        color=color,
        ha="left",
        va="center",
    )
    
ax.spines[['right', 'top']].set_visible(False)
custom_lines = [Line2D([0], [0], color=c, lw=1) for c in ("C0", "C1", "grey")]
ax.legend(custom_lines, ['positive relationship', 'negative relationship', 'inconclusive relationship'], 
           loc="upper center", ncol=4, bbox_to_anchor=(0.5, 1.1), frameon=False)
ax.set(ylabel="gdp (log, std)", xlabel="N_est (log std)");

# %% [markdown]
# #### Model comparison
#
# Finally, we execute a comparison across all models evaluated thus far. The comparison decisively underscores that incorporating varying slopes dramatically enhances the model fit, considerably outpacing the performance of the other models.

# %%
waic_compare = az.compare(models, ic='LOO')
waic_compare
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'log' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
#                                                     rank   elpd_loo  \
# log_gdp_std ~ score_log_std + (score_log_std|re...     0  96.055013
# log_gdp_std ~ N_est_log_std + (N_est_log_std|re...     1  94.620771
# log_gdp_std ~ N_est_log_std + (1|region_name)          2  94.361043
# log_gdp_std ~ score_log_std + (1|region_name)          3  94.249527
#
#                                                         p_loo  elpd_diff  \
# log_gdp_std ~ score_log_std + (score_log_std|re...  10.191902   0.000000
# log_gdp_std ~ N_est_log_std + (N_est_log_std|re...  10.173158   1.434242
# log_gdp_std ~ N_est_log_std + (1|region_name)        7.102702   1.693970
# log_gdp_std ~ score_log_std + (1|region_name)        7.235700   1.805485
#
#                                                           weight        se  \
# log_gdp_std ~ score_log_std + (score_log_std|re...  1.000000e+00  4.054355
# log_gdp_std ~ N_est_log_std + (N_est_log_std|re...  1.110223e-16  4.128734
# log_gdp_std ~ N_est_log_std + (1|region_name)       1.665335e-16  3.497571
# log_gdp_std ~ score_log_std + (1|region_name)       0.000000e+00  3.504112
#
#                                                          dse  warning scale
# log_gdp_std ~ score_log_std + (score_log_std|re...  0.000000     True   log
# log_gdp_std ~ N_est_log_std + (N_est_log_std|re...  0.361212     True   log
# log_gdp_std ~ N_est_log_std + (1|region_name)       1.674063    False   log
# log_gdp_std ~ score_log_std + (1|region_name)       1.683281    False   log

# %%
az.plot_compare(waic_compare.loc[waic_compare.index.str.contains("region_name")], insample_dev=True);
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/plots/backends/matplotlib/compareplot.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   scale = comp_df["scale"][0]

# %% [markdown]
# # Cultural score per capita

# %% [markdown]
# In the analsyses above, we correlated a global cultural production score (both corrected and uncorrected) with the GDP scores per capita. These scores ignore differences in population size. As a final step in the analysis, we repeat the analyses with varying intercepts and varying slopes, but swapping the unnormalized cultural production scores for the scores per capita. We begin with the uncorrected score:

# %%
priors = {
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
}

m_score_cap_vi = bmb.Model(
    "log_gdp_std ~ score_cap_log_std + (1|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True, 
    priors=priors
)
m_score_cap_vi
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score_cap_log_std'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 8
#       1 priors = {
#       2     "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
#       3     "common": bmb.Prior("Normal", mu=0, sigma=1),
#       4     "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
#       5     "sigma": bmb.Prior("Exponential", lam=1)
#       6 }
# ----> 8 m_score_cap_vi = bmb.Model(
#       9     "log_gdp_std ~ score_cap_log_std + (1|region_name)",
#      10     df,
#      11     family="gaussian",
#      12     noncentered=True,
#      13     priors=priors
#      14 )
#      15 m_score_cap_vi
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/bambi/models.py:168, in Model.__init__(self, formula, data, family, priors, link, categorical, potentials, dropna, auto_scale, noncentered, center_predictors, extra_namespace)
#     166     design = remove_common_intercept(design)
#     167 else:
# --> 168     design = fm.design_matrices(
#     169         self.formula.main, self.data, na_action, 1, additional_namespace
#     170     )
#     172 if design.response is None:
#     173     raise ValueError(
#     174         "No outcome variable is set! "
#     175         "Please specify an outcome variable using the formula interface."
#     176     )
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/formulae/matrices.py:556, in design_matrices(formula, data, na_action, env, extra_namespace)
#     553     else:
#     554         raise ValueError(f"'data' contains {incomplete_rows_n} incomplete rows.")
# --> 556 design = DesignMatrices(description, data, env)
#     557 return design
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/formulae/matrices.py:54, in DesignMatrices.__init__(self, model, data, env)
#      51 self.model = model
#      53 # Evaluate terms in the model
# ---> 54 self.model.eval(data, env)
#      56 if self.model.response:
#      57     self.response = ResponseMatrix(self.model.response)
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/formulae/terms/terms.py:1254, in Model.eval(self, data, env)
#    1244 """Evaluates terms in the model.
#    1245
#    1246 Parameters
#    (...)
#    1251     The environment where values and functions are taken from.
#    1252 """
#    1253 # Set types on all terms
# -> 1254 self.set_types(data, env)
#    1256 # Evaluate common terms
#    1257 encodings = self._get_encoding_bools()
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/formulae/terms/terms.py:1161, in Model.set_types(self, data, env)
#    1149 """Set the type of the terms in the model.
#    1150
#    1151 Calls ``.set_type()`` method on term in the model.
#    (...)
#    1158     The environment where values and functions are taken from.
#    1159 """
#    1160 for term in self.terms:
# -> 1161     term.set_type(data, env)
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/formulae/terms/terms.py:431, in Term.set_type(self, data, env)
#     429 for component in self.components:
#     430     if isinstance(component, Variable):
# --> 431         component.set_type(data)
#     432     elif isinstance(component, Call):
#     433         component.set_type(data, env)
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/formulae/terms/variable.py:84, in Variable.set_type(self, data_mask)
#      72 def set_type(self, data_mask):
#      73     """Detemines the type of the variable.
#      74
#      75     Looks for the name of the variable in ``data_mask`` and sets the ``.kind`` property to
#    (...)
#      82         The data frame where variables are taken from
#      83     """
# ---> 84     x = data_mask[self.name]
#      85     if is_numeric_dtype(x):
#      86         self.kind = "numeric"
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/Desktop/cultura_project/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'score_cap_log_std'

# %% [markdown]
# The model graph looks as follows:

# %%
m_score_cap_vi.build()
m_score_cap_vi.graph()

# %%
m_score_cap_vi_fit = m_score_cap_vi.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.9,
    idata_kwargs={"log_likelihood": True}
)
models["log_gdp_std ~ score_cap_log_std + (1|region_name)"] = m_score_cap_vi_fit
az.summary(m_score_cap_vi_fit)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, score_cap_log_std, 1|region_name_sigma, 1|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:11&lt;00:00 Sampling 4 chains, 10 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 12 seconds.
# There were 10 divergences after tuning. Increase `target_accept` or reparameterize.
#                                   mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# Intercept                        0.753  0.060   0.642    0.868      0.001
# score_cap_log_std                0.246  0.046   0.159    0.331      0.001
# log_gdp_std_sigma                0.021  0.003   0.017    0.026      0.000
# 1|region_name_sigma              0.089  0.041   0.037    0.164      0.001
# 1|region_name[Eastern Europe]   -0.071  0.041  -0.144    0.013      0.001
# 1|region_name[France]            0.009  0.041  -0.067    0.090      0.001
# 1|region_name[Italy]             0.048  0.041  -0.033    0.126      0.001
# 1|region_name[Low countries]     0.029  0.041  -0.048    0.110      0.001
# 1|region_name[Nordic countries] -0.085  0.042  -0.163   -0.005      0.001
# 1|region_name[United Kingdom]    0.071  0.041  -0.003    0.156      0.001
#
#                                  mcse_sd  ess_bulk  ess_tail  r_hat
# Intercept                          0.001    2394.0    2382.0    1.0
# score_cap_log_std                  0.000    4593.0    3585.0    1.0
# log_gdp_std_sigma                  0.000    4011.0    3701.0    1.0
# 1|region_name_sigma                0.001    1605.0    2061.0    1.0
# 1|region_name[Eastern Europe]      0.001    1319.0    1100.0    1.0
# 1|region_name[France]              0.001    1295.0    1157.0    1.0
# 1|region_name[Italy]               0.001    1343.0    1182.0    1.0
# 1|region_name[Low countries]       0.001    1292.0    1130.0    1.0
# 1|region_name[Nordic countries]    0.001    1304.0    1151.0    1.0
# 1|region_name[United Kingdom]      0.001    1317.0    1110.0    1.0

# %% [markdown]
# Once again, the sampling appears to be successful, reflected by desirable $\hat{r}$ values and substantial effective sample sizes. The findings hint at a minimal positive global correlation between cultural production and GDP (0.023 CI [0.022, 0.025]). It seems that the model fit is decent.

# %%
m_score_cap_vi.predict(m_score_cap_vi_fit, kind="pps")
az.plot_ppc(m_score_cap_vi_fit);

# %%
import xarray as xr

fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_score_cap_vi_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["score_cap_log_std"]
    score = np.array([-1.5, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = slope_common

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["score_cap_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="score per capita (log std)", title=region_name)

# %% [markdown]
# Here's another visualization of the posterior predictions: the intercepts differ, but the slope (_by design_) is the same, and thus always positive:

# %%
posterior = az.extract(m_score_cap_vi_fit)
intercept_common = posterior["Intercept"]
slope_common = posterior["score_cap_log_std"]
score = np.array([-1.5, 2])

intercept_group_specific = posterior["1|region_name"]
a = intercept_common.mean() + intercept_group_specific.mean("sample")
b = slope_common.mean()
score_xi = xr.DataArray(score)
plt.plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.7, lw=0.8)
plt.ylabel("gdp (log, std)")
plt.xlabel("Score per capita (log std)");

# %% [markdown]
# We perform the same analysis, swapping the cultural production score for the bias-corrected score:

# %%
priors = {
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
}

m_est_cap_vi = bmb.Model(
    "log_gdp_std ~ N_est_cap_log_std + (1|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True,
    priors=priors)
m_est_cap_vi
# Out:
#        Formula: log_gdp_std ~ N_est_cap_log_std + (1|region_name)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 45
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 1.0, sigma: 1.0)
#             N_est_cap_log_std ~ Normal(mu: 0.0, sigma: 1.0)
#
#         Group-level effects
#             1|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#
#         Auxiliary parameters
#             sigma ~ Exponential(lam: 1.0)

# %%
m_est_cap_vi_fit = m_est_cap_vi.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.9,
    idata_kwargs={"log_likelihood": True})

models["log_gdp_std ~ N_est_cap_log_std + (1|region_name)"] = m_est_cap_vi_fit
az.summary(m_est_cap_vi_fit)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, N_est_cap_log_std, 1|region_name_sigma, 1|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:13&lt;00:00 Sampling 4 chains, 20 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 13 seconds.
# There were 20 divergences after tuning. Increase `target_accept` or reparameterize.
#                                   mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# Intercept                        0.602  0.090   0.441    0.777      0.002
# N_est_cap_log_std                0.396  0.073   0.265    0.540      0.001
# log_gdp_std_sigma                0.021  0.003   0.016    0.026      0.000
# 1|region_name_sigma              0.115  0.051   0.045    0.207      0.001
# 1|region_name[Eastern Europe]   -0.113  0.051  -0.215   -0.016      0.001
# 1|region_name[France]            0.030  0.051  -0.069    0.128      0.001
# 1|region_name[Italy]             0.035  0.051  -0.060    0.138      0.001
# 1|region_name[Low countries]     0.050  0.051  -0.050    0.146      0.001
# 1|region_name[Nordic countries] -0.091  0.051  -0.192    0.006      0.001
# 1|region_name[United Kingdom]    0.097  0.051   0.004    0.203      0.001
#
#                                  mcse_sd  ess_bulk  ess_tail  r_hat
# Intercept                          0.001    2574.0    2606.0    1.0
# N_est_cap_log_std                  0.001    4779.0    4180.0    1.0
# log_gdp_std_sigma                  0.000    4282.0    4005.0    1.0
# 1|region_name_sigma                0.001    1332.0    1766.0    1.0
# 1|region_name[Eastern Europe]      0.001    1361.0    1616.0    1.0
# 1|region_name[France]              0.001    1343.0    1593.0    1.0
# 1|region_name[Italy]               0.001    1358.0    1625.0    1.0
# 1|region_name[Low countries]       0.001    1357.0    1606.0    1.0
# 1|region_name[Nordic countries]    0.001    1387.0    1693.0    1.0
# 1|region_name[United Kingdom]      0.001    1360.0    1590.0    1.0

# %% [markdown]
# The fit appears to bear similarity to the prior model, and once more, the incorporated unidirectional relationship yields comparatively large residuals.

# %%
import xarray as xr

fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_est_cap_vi_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["N_est_cap_log_std"]
    score = np.array([-1.5, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = slope_common

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["N_est_cap_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="N est per capita (log std)", title=region_name)

# %%
posterior = az.extract(m_est_cap_vi_fit)
intercept_common = posterior["Intercept"]
slope_common = posterior["N_est_cap_log_std"]
score = np.array([-1.5, 2])

intercept_group_specific = posterior["1|region_name"]
a = intercept_common.mean() + intercept_group_specific.mean("sample")
b = slope_common.mean()
score_xi = xr.DataArray(score)
plt.plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.7, lw=0.8)
plt.ylabel("gdp (log, std)")
plt.xlabel("N est per capita (log std)");

# %% [markdown]
# ### Varying Slopes for Cultural Production in Different Regions

# %%
priors = {
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "score_cap_log_std|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
}

m_score_cap_vs = bmb.Model(
    "log_gdp_std ~ score_cap_log_std + (score_cap_log_std|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True,
    priors=priors
)
m_score_cap_vs
# Out:
#        Formula: log_gdp_std ~ score_cap_log_std + (score_cap_log_std|region_name)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 45
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 1.0, sigma: 1.0)
#             score_cap_log_std ~ Normal(mu: 0.0, sigma: 1.0)
#
#         Group-level effects
#             1|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             score_cap_log_std|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#
#         Auxiliary parameters
#             sigma ~ Exponential(lam: 1.0)

# %% [markdown]
# The model graph looks as follows:

# %%
m_score_cap_vs.build()
m_score_cap_vs.graph()

# %%
m_score_cap_vs_fit = m_score_cap_vs.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.9,
    idata_kwargs={"log_likelihood": True})

models["log_gdp_std ~ score_cap_log_std + (score_cap_log_std|region_name)"] = m_score_cap_vs_fit
az.summary(m_score_cap_vs_fit)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, score_cap_log_std, 1|region_name_sigma, 1|region_name_offset, score_cap_log_std|region_name_sigma, score_cap_log_std|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:35&lt;00:00 Sampling 4 chains, 1,617 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 36 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# There were 1617 divergences after tuning. Increase `target_accept` or reparameterize.
#                                                   mean     sd  hdi_3%  \
# Intercept                                        0.783  0.084   0.655
# score_cap_log_std                                0.204  0.097   0.015
# log_gdp_std_sigma                                0.020  0.003   0.017
# 1|region_name_sigma                              0.118  0.060   0.026
# score_cap_log_std|region_name_sigma              0.093  0.080   0.000
# 1|region_name[Eastern Europe]                   -0.138  0.118  -0.373
# 1|region_name[France]                           -0.053  0.105  -0.251
# 1|region_name[Italy]                             0.098  0.072  -0.025
# 1|region_name[Low countries]                     0.029  0.055  -0.079
# 1|region_name[Nordic countries]                 -0.114  0.092  -0.271
# 1|region_name[United Kingdom]                    0.057  0.057  -0.053
# score_cap_log_std|region_name[Eastern Europe]    0.084  0.138  -0.071
# score_cap_log_std|region_name[France]            0.076  0.121  -0.052
# score_cap_log_std|region_name[Italy]            -0.052  0.068  -0.160
# score_cap_log_std|region_name[Low countries]     0.015  0.054  -0.071
# score_cap_log_std|region_name[Nordic countries]  0.041  0.101  -0.078
# score_cap_log_std|region_name[United Kingdom]    0.028  0.059  -0.080
#
#                                                  hdi_97%  mcse_mean  mcse_sd  \
# Intercept                                          0.930      0.030    0.023
# score_cap_log_std                                  0.325      0.040    0.030
# log_gdp_std_sigma                                  0.026      0.001    0.000
# 1|region_name_sigma                                0.212      0.011    0.008
# score_cap_log_std|region_name_sigma                0.229      0.032    0.024
# 1|region_name[Eastern Europe]                      0.010      0.050    0.040
# 1|region_name[France]                              0.086      0.043    0.035
# 1|region_name[Italy]                               0.205      0.020    0.015
# 1|region_name[Low countries]                       0.137      0.004    0.003
# 1|region_name[Nordic countries]                    0.019      0.035    0.028
# 1|region_name[United Kingdom]                      0.171      0.004    0.005
# score_cap_log_std|region_name[Eastern Europe]      0.365      0.061    0.049
# score_cap_log_std|region_name[France]              0.315      0.053    0.042
# score_cap_log_std|region_name[Italy]               0.058      0.019    0.013
# score_cap_log_std|region_name[Low countries]       0.119      0.017    0.012
# score_cap_log_std|region_name[Nordic countries]    0.233      0.044    0.034
# score_cap_log_std|region_name[United Kingdom]      0.116      0.016    0.012
#
#                                                  ess_bulk  ess_tail  r_hat
# Intercept                                            10.0      21.0   1.34
# score_cap_log_std                                     8.0      15.0   1.40
# log_gdp_std_sigma                                    14.0     183.0   1.19
# 1|region_name_sigma                                  22.0    1658.0   1.12
# score_cap_log_std|region_name_sigma                  10.0      39.0   1.32
# 1|region_name[Eastern Europe]                         8.0      12.0   1.44
# 1|region_name[France]                                 8.0      23.0   1.40
# 1|region_name[Italy]                                 15.0     732.0   1.18
# 1|region_name[Low countries]                        116.0    1728.0   1.04
# 1|region_name[Nordic countries]                      10.0      70.0   1.33
# 1|region_name[United Kingdom]                       139.0    2463.0   1.11
# score_cap_log_std|region_name[Eastern Europe]         8.0      11.0   1.46
# score_cap_log_std|region_name[France]                 8.0      33.0   1.42
# score_cap_log_std|region_name[Italy]                 17.0    1364.0   1.16
# score_cap_log_std|region_name[Low countries]         11.0      27.0   1.28
# score_cap_log_std|region_name[Nordic countries]       9.0      45.0   1.40
# score_cap_log_std|region_name[United Kingdom]        14.0    1109.0   1.20

# %% [markdown]
# Echoing our previous approach, we conduct a posterior predictive check and find that the model aligns with the data far more effectively. The difference with the simpler models is really remarkable:

# %%
m_score_cap_vs.predict(m_score_cap_vs_fit, kind="pps")
az.plot_ppc(m_score_cap_vs_fit);

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_score_cap_vs_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["score_cap_log_std"]
    score = np.array([-1.5, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    slope_specific_0 = posterior["score_cap_log_std|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = (slope_common + slope_specific_0)

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["score_cap_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="score per capita (log std)", title=region_name)

# %%
from matplotlib.lines import Line2D

intercept_group_specific = posterior["1|region_name"]
slope_group_specific = posterior["score_cap_log_std|region_name"]

a = intercept_common + intercept_group_specific
b = slope_common + slope_group_specific

score_xi = xr.DataArray(score)

fig, ax = plt.subplots()
for region in df["region_name"].unique():

    a_region = a.sel(region_name__factor_dim=region)
    b_region = b.sel(region_name__factor_dim=region)
    
    Y = (a_region + b_region * score_xi)
    Y_mean = Y.mean(axis=0)

    color = ("C0" if (Y[:, 1].quantile(0.025) > Y[:, 0].quantile(0.975)) else 
             "C1" if (Y[:, 0].quantile(0.025) > Y[:, 1].quantile(0.975)) else 
             "grey")
    ax.plot(score_xi, Y_mean, color=color, alpha=0.7, lw=0.8, label=region)
    ax.text(
        score_xi[-1],
        Y_mean[-1],
        " — " + region,
        size="small",
        color=color,
        ha="left",
        va="center",
    )
    
ax.spines[['right', 'top']].set_visible(False)
custom_lines = [Line2D([0], [0], color=c, lw=1) for c in ("C0", "C1", "grey")]
ax.legend(custom_lines, ['positive relationship', 'negative relationship', 'inconclusive relationship'], 
           loc="upper center", ncol=4, bbox_to_anchor=(0.5, 1.1), frameon=False)
ax.set(ylabel="gdp (log, std)", xlabel="score per capita (log std)");

# %% [markdown]
# Below, I repeat the analysis, again swapping cultural production for the bias-corrected score.

# %%
priors = {
    "Intercept": bmb.Prior("Normal", mu=1, sigma=1),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "1|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "N_est_cap_log_std|region_name": bmb.Prior("Normal", mu=0, sigma=bmb.Prior("HalfNormal", sigma=1)),
    "sigma": bmb.Prior("Exponential", lam=1)
}

m_est_cap_vs = bmb.Model(
    "log_gdp_std ~  N_est_cap_log_std + (N_est_cap_log_std|region_name)", 
    df, 
    family="gaussian", 
    noncentered=True,
    priors=priors
)
m_est_cap_vs
# Out:
#        Formula: log_gdp_std ~  N_est_cap_log_std + (N_est_cap_log_std|region_name)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 45
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 1.0, sigma: 1.0)
#             N_est_cap_log_std ~ Normal(mu: 0.0, sigma: 1.0)
#
#         Group-level effects
#             1|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             N_est_cap_log_std|region_name ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#
#         Auxiliary parameters
#             sigma ~ Exponential(lam: 1.0)

# %%
m_est_cap_vs_fit = m_est_cap_vs.fit(
    draws=2000, 
    chains=4, 
    target_accept=0.95,
    idata_kwargs={"log_likelihood": True})

models["log_gdp_std ~ N_est_cap_log_std + (N_est_cap_log_std|region_name)"] = m_est_cap_vs_fit
az.summary(m_est_cap_vs_fit)

# NB: hitting max_treedepth is not much of a concern, at least not for model validity
# For more information about this and other warnings, see https://mc-stan.org/misc/warnings.html
# TODO, see if we can improve efficiency
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [log_gdp_std_sigma, Intercept, N_est_cap_log_std, 1|region_name_sigma, 1|region_name_offset, N_est_cap_log_std|region_name_sigma, N_est_cap_log_std|region_name_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 01:05&lt;00:00 Sampling 4 chains, 108 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 65 seconds.
# There were 108 divergences after tuning. Increase `target_accept` or reparameterize.
#                                                   mean     sd  hdi_3%  \
# Intercept                                        0.597  0.095   0.415
# N_est_cap_log_std                                0.401  0.085   0.233
# log_gdp_std_sigma                                0.021  0.003   0.016
# 1|region_name_sigma                              0.132  0.084   0.005
# N_est_cap_log_std|region_name_sigma              0.079  0.076   0.000
# 1|region_name[Eastern Europe]                   -0.120  0.093  -0.322
# 1|region_name[France]                            0.008  0.079  -0.156
# 1|region_name[Italy]                             0.072  0.096  -0.086
# 1|region_name[Low countries]                     0.047  0.080  -0.112
# 1|region_name[Nordic countries]                 -0.080  0.084  -0.244
# 1|region_name[United Kingdom]                    0.076  0.084  -0.079
# N_est_cap_log_std|region_name[Eastern Europe]    0.007  0.083  -0.145
# N_est_cap_log_std|region_name[France]            0.025  0.071  -0.102
# N_est_cap_log_std|region_name[Italy]            -0.038  0.084  -0.239
# N_est_cap_log_std|region_name[Low countries]     0.003  0.067  -0.131
# N_est_cap_log_std|region_name[Nordic countries] -0.010  0.068  -0.161
# N_est_cap_log_std|region_name[United Kingdom]    0.023  0.076  -0.117
#
#                                                  hdi_97%  mcse_mean  mcse_sd  \
# Intercept                                          0.772      0.001    0.001
# N_est_cap_log_std                                  0.556      0.001    0.001
# log_gdp_std_sigma                                  0.026      0.000    0.000
# 1|region_name_sigma                                0.278      0.002    0.001
# N_est_cap_log_std|region_name_sigma                0.208      0.002    0.001
# 1|region_name[Eastern Europe]                      0.024      0.002    0.002
# 1|region_name[France]                              0.156      0.001    0.001
# 1|region_name[Italy]                               0.276      0.002    0.002
# 1|region_name[Low countries]                       0.194      0.001    0.001
# 1|region_name[Nordic countries]                    0.071      0.002    0.001
# 1|region_name[United Kingdom]                      0.241      0.001    0.001
# N_est_cap_log_std|region_name[Eastern Europe]      0.185      0.002    0.001
# N_est_cap_log_std|region_name[France]              0.172      0.001    0.001
# N_est_cap_log_std|region_name[Italy]               0.086      0.002    0.001
# N_est_cap_log_std|region_name[Low countries]       0.139      0.001    0.001
# N_est_cap_log_std|region_name[Nordic countries]    0.116      0.001    0.001
# N_est_cap_log_std|region_name[United Kingdom]      0.177      0.001    0.001
#
#                                                  ess_bulk  ess_tail  r_hat
# Intercept                                          4511.0    3896.0    1.0
# N_est_cap_log_std                                  4692.0    3642.0    1.0
# log_gdp_std_sigma                                  4089.0    4323.0    1.0
# 1|region_name_sigma                                1625.0    2120.0    1.0
# N_est_cap_log_std|region_name_sigma                1625.0    2661.0    1.0
# 1|region_name[Eastern Europe]                      2212.0    2208.0    1.0
# 1|region_name[France]                              2972.0    3178.0    1.0
# 1|region_name[Italy]                               2247.0    2697.0    1.0
# 1|region_name[Low countries]                       3226.0    3050.0    1.0
# 1|region_name[Nordic countries]                    3196.0    3289.0    1.0
# 1|region_name[United Kingdom]                      3349.0    3389.0    1.0
# N_est_cap_log_std|region_name[Eastern Europe]      2137.0    2282.0    1.0
# N_est_cap_log_std|region_name[France]              3729.0    2719.0    1.0
# N_est_cap_log_std|region_name[Italy]               2544.0    3202.0    1.0
# N_est_cap_log_std|region_name[Low countries]       3686.0    3178.0    1.0
# N_est_cap_log_std|region_name[Nordic countries]    3222.0    2383.0    1.0
# N_est_cap_log_std|region_name[United Kingdom]      3981.0    3377.0    1.0

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 5), constrained_layout=True)
axes = axes.flatten()

for i, region_name in enumerate(df["region_name"].unique()):

    data_0 = df[df["region_name"] == region_name]

    posterior = az.extract(m_est_cap_vs_fit)
    intercept_common = posterior["Intercept"]
    slope_common = posterior["N_est_cap_log_std"]
    score = np.array([-1.5, 2])

    intercept_specific_0 = posterior["1|region_name"].sel(region_name__factor_dim=region_name)
    slope_specific_0 = posterior["N_est_cap_log_std|region_name"].sel(region_name__factor_dim=region_name)
    a = (intercept_common + intercept_specific_0)
    b = (slope_common + slope_specific_0)

    score_xi = xr.DataArray(score)
    axes[i].plot(score_xi, (a + b * score_xi).T, color="C1", alpha=0.2, lw=0.1)
    axes[i].plot(score_xi, a.mean() + b.mean() * score_xi, color="black")
    axes[i].scatter(data_0["N_est_cap_log_std"], data_0["log_gdp_std"], zorder=2, s=20, 
                    facecolors="none", edgecolors='grey')
    axes[i].set(ylabel="gdp (log, std)", xlabel="N_est per capita (log std)", title=region_name)

# %%
from matplotlib.lines import Line2D

intercept_group_specific = posterior["1|region_name"]
slope_group_specific = posterior["N_est_cap_log_std|region_name"]

a = intercept_common + intercept_group_specific
b = slope_common + slope_group_specific

score_xi = xr.DataArray(score)

fig, ax = plt.subplots()
for region in df["region_name"].unique():

    a_region = a.sel(region_name__factor_dim=region)
    b_region = b.sel(region_name__factor_dim=region)
    
    Y = (a_region + b_region * score_xi)
    Y_mean = Y.mean(axis=0)

    color = ("C0" if (Y[:, 1].quantile(0.025) > Y[:, 0].quantile(0.975)) else 
             "C1" if (Y[:, 0].quantile(0.025) > Y[:, 1].quantile(0.975)) else 
             "grey")
    ax.plot(score_xi, Y_mean, color=color, alpha=0.7, lw=0.8, label=region)
    ax.text(
        score_xi[-1],
        Y_mean[-1],
        " — " + region,
        size="small",
        color=color,
        ha="left",
        va="center",
    )
    
ax.spines[['right', 'top']].set_visible(False)
custom_lines = [Line2D([0], [0], color=c, lw=1) for c in ("C0", "C1", "grey")]
ax.legend(custom_lines, ['positive relationship', 'negative relationship', 'inconclusive relationship'], 
           loc="upper center", ncol=4, bbox_to_anchor=(0.5, 1.1), frameon=False)
ax.set(ylabel="gdp (log, std)", xlabel="N_est per capita (log std)");

fig.savefig('results_BRM/gpd_index_relationship.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from matplotlib.lines import Line2D
# ----> 3 intercept_group_specific = posterior["1|region_name"]
#       4 slope_group_specific = posterior["N_est_cap_log_std|region_name"]
#       6 a = intercept_common + intercept_group_specific
#
# NameError: name 'posterior' is not defined

# %% [markdown]
# #### Model comparison
#
# Finally, we execute a comparison across all models evaluated thus far. The comparison decisively underscores that incorporating varying slopes dramatically enhances the model fit, considerably outpacing the performance of the other models. Furthermore, we note that the bias-correction does not improve the model fit considerably. Finally, representing the cultural scores per capita does not improve the model fit either.

# %%
waic_compare = az.compare(models, ic='LOO')
# Out:
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (
# /Users/charlesdedampierre/Desktop/cultura_project/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:307: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'log' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_comp.loc[val] = (

# %%
waic_compare['elpd_loo'] = round(waic_compare['elpd_loo'], 0)

# %%
waic_compare
# Out:
#                                                     rank  elpd_loo      p_loo  \
# log_gdp_std ~ N_est_log_std + (N_est_log_std|re...     0     123.0  10.539564
# log_gdp_std ~ score_log_std + (score_log_std|re...     1     122.0   9.891605
# log_gdp_std ~ N_est_log_std + (1|region_name)          2     118.0   6.935156
# log_gdp_std ~ score_log_std + (1|region_name)          3     117.0   6.910282
# log_gdp_std ~ score_cap_log_std + (score_cap_lo...     4     107.0   8.119727
# log_gdp_std ~ N_est_cap_log_std + (1|region_name)      5     107.0   7.010814
# log_gdp_std ~ N_est_cap_log_std + (N_est_cap_lo...     6     107.0   7.585019
# log_gdp_std ~ score_cap_log_std + (1|region_name)      7     106.0   7.036274
# log_gdp_std ~ (1|region_name)                          8      93.0   6.125170
# gdp ~ N_est_log_std                                    9      60.0   2.593502
# gdp ~ score_log_std                                   10      59.0   2.372548
#
#                                                     elpd_diff  weight  \
# log_gdp_std ~ N_est_log_std + (N_est_log_std|re...   0.000000     1.0
# log_gdp_std ~ score_log_std + (score_log_std|re...   0.391933     0.0
# log_gdp_std ~ N_est_log_std + (1|region_name)        5.068594     0.0
# log_gdp_std ~ score_log_std + (1|region_name)        6.054229     0.0
# log_gdp_std ~ score_cap_log_std + (score_cap_lo...  15.797280     0.0
# log_gdp_std ~ N_est_cap_log_std + (1|region_name)   15.868757     0.0
# log_gdp_std ~ N_est_cap_log_std + (N_est_cap_lo...  15.902052     0.0
# log_gdp_std ~ score_cap_log_std + (1|region_name)   16.922723     0.0
# log_gdp_std ~ (1|region_name)                       29.275043     0.0
# gdp ~ N_est_log_std                                 62.579758     0.0
# gdp ~ score_log_std                                 64.066614     0.0
#
#                                                           se       dse  \
# log_gdp_std ~ N_est_log_std + (N_est_log_std|re...  4.069668  0.000000
# log_gdp_std ~ score_log_std + (score_log_std|re...  3.978196  0.577731
# log_gdp_std ~ N_est_log_std + (1|region_name)       3.663768  2.263086
# log_gdp_std ~ score_log_std + (1|region_name)       3.603886  2.253415
# log_gdp_std ~ score_cap_log_std + (score_cap_lo...  4.596246  2.653888
# log_gdp_std ~ N_est_cap_log_std + (1|region_name)   4.363700  2.497221
# log_gdp_std ~ N_est_cap_log_std + (N_est_cap_lo...  4.491390  2.499807
# log_gdp_std ~ score_cap_log_std + (1|region_name)   4.295392  2.535101
# log_gdp_std ~ (1|region_name)                       3.747279  4.451814
# gdp ~ N_est_log_std                                 4.120140  5.235621
# gdp ~ score_log_std                                 4.203485  4.636245
#
#                                                     warning scale
# log_gdp_std ~ N_est_log_std + (N_est_log_std|re...     True   log
# log_gdp_std ~ score_log_std + (score_log_std|re...     True   log
# log_gdp_std ~ N_est_log_std + (1|region_name)         False   log
# log_gdp_std ~ score_log_std + (1|region_name)         False   log
# log_gdp_std ~ score_cap_log_std + (score_cap_lo...    False   log
# log_gdp_std ~ N_est_cap_log_std + (1|region_name)     False   log
# log_gdp_std ~ N_est_cap_log_std + (N_est_cap_lo...    False   log
# log_gdp_std ~ score_cap_log_std + (1|region_name)     False   log
# log_gdp_std ~ (1|region_name)                         False   log
# gdp ~ N_est_log_std                                   False   log
# gdp ~ score_log_std                                   False   log

# %%
# Your existing code to create the plot
axes = az.plot_compare(waic_compare.loc[waic_compare.index.str.contains("region_name")], insample_dev=True)

# Get the figure from the axes
fig = axes.figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Your existing code to create the plot
# ----> 2 axes = az.plot_compare(waic_compare.loc[waic_compare.index.str.contains("region_name")], insample_dev=True)
#       4 # Get the figure from the axes
#       5 fig = axes.figure
#
# NameError: name 'az' is not defined

# %%
# Save the figure to a file
fig.savefig('results_BRM/model_comparison', dpi=300)
